# %%
# Mutation Simulation experiments (Currently converting from old working directory to new working directory

# Author Fraser Toon

# %%
# Imports needed
import os
import subprocess
import helpers
import pandas
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import re
import numpy

# %%
# Number of genomes for the test: 384
# Filters are:
# Type: Escherichia
# Length: Complete
# Year: 2024-2024
# Condition (?): Annotated

# %%
# Specify the starting directory
start_directory = '/home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data'

# Arrays to hold directories and file names
directories = []
file_names = []

# Traverse the directory tree
for root, dirs, files in os.walk(start_directory):
    for file in files:
        if file.endswith('genomic.fna') and "SNP" not in file:
            directories.append(root)
            file_names.append(file)

print(f"Done: {len(directories), len(file_names)}")

# Make full path of original files
index = 0
original_genomes = []
if directories and file_names:
    for first_directory, first_fna_file in zip(directories, file_names):
        file_location = first_directory + "/" + first_fna_file
        original_genomes.append(file_location)
        index = index + 1

else:
    print("No .fna files found.")

print(f"Done: {len(original_genomes)}")
# Out:
# Done: (384, 384)
# Done: 384

# %%
contents = []
contents_length = []
# Process each file in the file_paths list
for file_path in original_genomes:
    with open(file_path, "r") as file:
        # Read all lines from the file
        lines = file.readlines()
        # Initialize an empty string to hold the content of the current file
        content = ""
        # Process each line, skipping the first line
        for line in lines[1:]:
            # Remove newline characters and concatenate to the content string
            content += line.strip()
            
        # Append the processed content to the contents list
        contents.append(content)
        contents_length.append(len(content))

print(f"Done: {len(contents)}, {len(contents_length)}")
# Out:
# Done: 384, 384

# %%
index = 0
rate = [0.05]
for SNP_rate in rate:
    if directories and file_names:
        for first_directory, first_fna_file in zip(directories, file_names):

             # Amount of SNPs for 5%
            SNP_amount = int(contents_length[index]) * 0.05
            SNP_count = int(SNP_amount)

            #SNP_count = int(round(int(contents_length[0]) * rate, 0))

            index = index + 1
            print(f'{index}: {first_directory} -> {first_fna_file}')

            command = f'cd {first_directory} && echo "SNP Rate: 0.05\nChanges: {SNP_count}" > SNP_Changes.txt'

            try:
                # Run the command in the shell with a timeout of 3 minutes
                result = subprocess.run(command, shell=True, timeout=3*60, stderr=subprocess.PIPE, universal_newlines=True)

                # Print stderr output
                if result.stderr:
                    print(result.stderr)
                
            except subprocess.TimeoutExpired as e:
                print(f"Command timed out: {e}")
            except Exception as e:
                print(f"An error occurred: {e}")

            command = f' cd {first_directory} && (/usr/bin/time -v perl /home/ftoon/Tests/simuG/simuG.pl -refseq {first_directory + "/" + first_fna_file} -snp_count {SNP_count} -prefix {SNP_rate}_SNP_Test) > time.txt 2>&1'
            #command = f'cd {first_directory} && perl /Users/frasertoon/Documents/Uni/EGH400-2/Testing/simuG/simuG.pl -refseq {first_directory + "/" + first_fna_file} -snp_count {SNP_count} -prefix {SNP_rate}_SNP_Test'
            try:
                # Run the command in the shell with a timeout of 3 minutes
                result = subprocess.run(command, shell=True, timeout=3*60, stderr=subprocess.PIPE, universal_newlines=True)

                # Print stderr output
                if result.stderr:
                    print(result.stderr)
                
            except subprocess.TimeoutExpired as e:
                print(f"Command timed out: {e}")
            except Exception as e:
                print(f"An error occurred: {e}")
    else:
        print("No .fna files found.")

print("Done")
# Out:
# 1: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884635.1 -> GCF_036884635.1_ASM3688463v1_genomic.fna
# 2: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884625.1 -> GCF_036884625.1_ASM3688462v1_genomic.fna
# 3: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039912475.1 -> GCF_039912475.1_ASM3991247v1_genomic.fna
# 4: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036923505.1 -> GCF_036923505.1_STEC28_genomic.fna
# 5: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037914955.1 -> GCF_037914955.1_pKPC_NDMdeltaNDM_genomic.fna
# 6: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039912655.1 -> GCF_039912655.1_ASM3991265v1_genomic.fna
# 7: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039583295.1 -> GCF_039583295.1_ASM3958329v1_genomic.fna
# 8: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964053065.1 -> GCF_964053065.1_30859_5_287_genomic.fna
# 9: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040267585.1 -> GCF_040267585.1_MRSN129130_genomic.fna
# 10: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884765.1 -> GCF_036884765.1_ASM3688476v1_genomic.fna
# 11: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035974135.1 -> GCF_035974135.1_ASM3597413v1_genomic.fna
# 12: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040267555.1 -> GCF_040267555.1_MRSN146_genomic.fna
# 13: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040834075.1 -> GCF_040834075.1_ASM4083407v1_genomic.fna
# 14: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040551675.1 -> GCF_040551675.1_ASM4055167v1_genomic.fna
# 15: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040267445.1 -> GCF_040267445.1_ASM4026744v1_genomic.fna
# 16: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037555585.1 -> GCF_037555585.1_ASM3755558v1_genomic.fna
# 17: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037760445.1 -> GCF_037760445.1_ASM3776044v1_genomic.fna
# 18: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039909425.1 -> GCF_039909425.1_ASM3990942v1_genomic.fna
# 19: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036818325.1 -> GCF_036818325.1_ASM3681832v1_genomic.fna
# 20: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039583305.1 -> GCF_039583305.1_ASM3958330v1_genomic.fna
# 21: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964047955.1 -> GCF_964047955.1_30224_1_291_genomic.fna
# 22: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884355.1 -> GCF_036884355.1_ASM3688435v1_genomic.fna
# 23: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040215555.1 -> GCF_040215555.1_ASM4021555v1_genomic.fna
# 24: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884645.1 -> GCF_036884645.1_ASM3688464v1_genomic.fna
# 25: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035621115.1 -> GCF_035621115.1_ASM3562111v1_genomic.fna
# 26: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_030939765.1 -> GCF_030939765.1_ASM3093976v2_genomic.fna
# 27: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039909525.1 -> GCF_039909525.1_ASM3990952v1_genomic.fna
# 28: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040105125.1 -> GCF_040105125.1_NS30_genomic.fna
# 29: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964045445.1 -> GCF_964045445.1_30224_1_355_genomic.fna
# 30: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039654195.1 -> GCF_039654195.1_ASM3965419v1_genomic.fna
# 31: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040703075.1 -> GCF_040703075.1_ASM4070307v1_genomic.fna
# 32: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_041021995.1 -> GCF_041021995.1_ASM4102199v1_genomic.fna
# 33: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964043425.1 -> GCF_964043425.1_30348_2_256_genomic.fna
# 34: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037584545.1 -> GCF_037584545.1_ASM3758454v1_genomic.fna
# 35: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037525705.1 -> GCF_037525705.1_ASM3752570v1_genomic.fna
# 36: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_034338325.2 -> GCF_034338325.2_ASM3433832v2_genomic.fna
# 37: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039909515.1 -> GCF_039909515.1_ASM3990951v1_genomic.fna
# 38: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037575275.1 -> GCF_037575275.1_ASM3757527v1_genomic.fna
# 39: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037573545.1 -> GCF_037573545.1_ASM3757354v1_genomic.fna
# 40: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037558665.1 -> GCF_037558665.1_ASM3755866v1_genomic.fna
# 41: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038248495.1 -> GCF_038248495.1_ASM3824849v1_genomic.fna
# 42: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035557515.1 -> GCF_035557515.1_ASM3555751v2_genomic.fna
# 43: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035972895.1 -> GCF_035972895.1_ASM3597289v1_genomic.fna
# 44: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_041005895.1 -> GCF_041005895.1_W46_genomic.fna
# 45: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040543495.1 -> GCF_040543495.1_ASM4054349v1_genomic.fna
# 46: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035974095.1 -> GCF_035974095.1_ASM3597409v1_genomic.fna
# 47: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036785845.1 -> GCF_036785845.1_ASM3678584v1_genomic.fna
# 48: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040959095.1 -> GCF_040959095.1_ASM4095909v1_genomic.fna
# 49: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037756885.1 -> GCF_037756885.1_ASM3775688v1_genomic.fna
# 50: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040550895.1 -> GCF_040550895.1_ASM4055089v1_genomic.fna
# 51: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_019585785.2 -> GCF_019585785.2_STEC3_genomic.fna
# 52: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038096105.1 -> GCF_038096105.1_ASM3809610v1_genomic.fna
# 53: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040783495.1 -> GCF_040783495.1_ASM4078349v1_genomic.fna
# 54: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036702845.1 -> GCF_036702845.1_ASM3670284v1_genomic.fna
# 55: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040438625.1 -> GCF_040438625.1_ASM4043862v1_genomic.fna
# 56: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396505.1 -> GCF_038396505.1_ASM3839650v1_genomic.fna
# 57: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037890705.1 -> GCF_037890705.1_ASM3789070v1_genomic.fna
# 58: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037576255.1 -> GCF_037576255.1_ASM3757625v1_genomic.fna
# 59: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035621615.1 -> GCF_035621615.1_ASM3562161v1_genomic.fna
# 60: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037273335.1 -> GCF_037273335.1_ASM3727333v1_genomic.fna
# 61: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040268295.1 -> GCF_040268295.1_ASM4026829v1_genomic.fna
# 62: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396495.1 -> GCF_038396495.1_ASM3839649v1_genomic.fna
# 63: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037081875.1 -> GCF_037081875.1_ASM3708187v1_genomic.fna
# 64: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_029870635.2 -> GCF_029870635.2_ASM2987063v2_genomic.fna
# 65: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039851985.1 -> GCF_039851985.1_ASM3985198v1_genomic.fna
# 66: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040267565.1 -> GCF_040267565.1_MRSN23713_genomic.fna
# 67: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_041004245.1 -> GCF_041004245.1_W150_genomic.fna
# 68: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040267615.1 -> GCF_040267615.1_MRSN116333_genomic.fna
# 69: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884535.1 -> GCF_036884535.1_ASM3688453v1_genomic.fna
# 70: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037287445.1 -> GCF_037287445.1_ASM3728744v1_genomic.fna
# 71: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037744325.1 -> GCF_037744325.1_ASM3774432v1_genomic.fna
# 72: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040267595.1 -> GCF_040267595.1_MRSN130119_genomic.fna
# 73: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884615.1 -> GCF_036884615.1_ASM3688461v1_genomic.fna
# 74: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037101415.1 -> GCF_037101415.1_ASM3710141v1_genomic.fna
# 75: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884805.1 -> GCF_036884805.1_ASM3688480v1_genomic.fna
# 76: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037082015.1 -> GCF_037082015.1_ASM3708201v1_genomic.fna
# 77: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964049475.1 -> GCF_964049475.1_30345_1_220_genomic.fna
# 78: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036287685.1 -> GCF_036287685.1_ASM3628768v1_genomic.fna
# 79: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037526635.1 -> GCF_037526635.1_ASM3752663v1_genomic.fna
# 80: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037540695.1 -> GCF_037540695.1_ASM3754069v1_genomic.fna
# 81: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884405.1 -> GCF_036884405.1_ASM3688440v1_genomic.fna
# 82: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036452055.1 -> GCF_036452055.1_ASM3645205v1_genomic.fna
# 83: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036287725.1 -> GCF_036287725.1_ASM3628772v1_genomic.fna
# 84: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037565025.1 -> GCF_037565025.1_ASM3756502v1_genomic.fna
# 85: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964049185.1 -> GCF_964049185.1_30859_5_32_genomic.fna
# 86: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_020526785.2 -> GCF_020526785.2_ASM2052678v2_genomic.fna
# 87: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884435.1 -> GCF_036884435.1_ASM3688443v1_genomic.fna
# 88: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964046655.1 -> GCF_964046655.1_30224_1_273_genomic.fna
# 89: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884755.1 -> GCF_036884755.1_ASM3688475v1_genomic.fna
# 90: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040551235.1 -> GCF_040551235.1_ASM4055123v1_genomic.fna
# 91: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037482115.1 -> GCF_037482115.1_ASM3748211v1_genomic.fna
# 92: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036687395.1 -> GCF_036687395.1_ASM3668739v1_genomic.fna
# 93: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040931675.1 -> GCF_040931675.1_ASM4093167v1_genomic.fna
# 94: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037549885.1 -> GCF_037549885.1_ASM3754988v1_genomic.fna
# 95: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964048075.1 -> GCF_964048075.1_30821_1_280_genomic.fna
# 96: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_019585465.2 -> GCF_019585465.2_STEC10_genomic.fna
# 97: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037081985.1 -> GCF_037081985.1_ASM3708198v1_genomic.fna
# 98: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037287415.1 -> GCF_037287415.1_ASM3728741v1_genomic.fna
# 99: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040543435.1 -> GCF_040543435.1_ASM4054343v1_genomic.fna
# 100: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040555885.1 -> GCF_040555885.1_ASM4055588v1_genomic.fna
# 101: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_034337405.2 -> GCF_034337405.2_ASM3433740v2_genomic.fna
# 102: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884385.1 -> GCF_036884385.1_ASM3688438v1_genomic.fna
# 103: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040267775.1 -> GCF_040267775.1_ASM4026777v1_genomic.fna
# 104: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040549815.1 -> GCF_040549815.1_ASM4054981v1_genomic.fna
# 105: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_008364435.2 -> GCF_008364435.2_ASM836443v2_genomic.fna
# 106: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037094505.1 -> GCF_037094505.1_ASM3709450v1_genomic.fna
# 107: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036287825.1 -> GCF_036287825.1_ASM3628782v1_genomic.fna
# 108: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037527585.1 -> GCF_037527585.1_ASM3752758v1_genomic.fna
# 109: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036362825.1 -> GCF_036362825.1_ASM3636282v1_genomic.fna
# 110: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037094515.1 -> GCF_037094515.1_ASM3709451v1_genomic.fna
# 111: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037287455.1 -> GCF_037287455.1_ASM3728745v1_genomic.fna
# 112: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037100245.1 -> GCF_037100245.1_ASM3710024v1_genomic.fna
# 113: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037225585.1 -> GCF_037225585.1_ASM3722558v1_genomic.fna
# 114: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_020526745.2 -> GCF_020526745.2_ASM2052674v2_genomic.fna
# 115: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037553545.1 -> GCF_037553545.1_ASM3755354v1_genomic.fna
# 116: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964038595.1 -> GCF_964038595.1_30348_2_44_genomic.fna
# 117: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036923335.1 -> GCF_036923335.1_STEC26_genomic.fna
# 118: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_020526725.2 -> GCF_020526725.2_ASM2052672v2_genomic.fna
# 119: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884795.1 -> GCF_036884795.1_ASM3688479v1_genomic.fna
# 120: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037094555.1 -> GCF_037094555.1_ASM3709455v1_genomic.fna
# 121: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396545.1 -> GCF_038396545.1_ASM3839654v1_genomic.fna
# 122: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038096115.1 -> GCF_038096115.1_ASM3809611v1_genomic.fna
# 123: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396705.1 -> GCF_038396705.1_ASM3839670v1_genomic.fna
# 124: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964054695.1 -> GCF_964054695.1_30821_1_335_genomic.fna
# 125: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038627065.1 -> GCF_038627065.1_ASM3862706v2_genomic.fna
# 126: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039555125.1 -> GCF_039555125.1_ASM3955512v1_genomic.fna
# 127: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037553955.1 -> GCF_037553955.1_ASM3755395v1_genomic.fna
# 128: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040543575.1 -> GCF_040543575.1_ASM4054357v1_genomic.fna
# 129: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035621515.1 -> GCF_035621515.1_ASM3562151v1_genomic.fna
# 130: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964040665.1 -> GCF_964040665.1_30224_1_201_genomic.fna
# 131: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037920625.1 -> GCF_037920625.1_ASM3792062v1_genomic.fna
# 132: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039912505.1 -> GCF_039912505.1_ASM3991250v1_genomic.fna
# 133: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040554385.1 -> GCF_040554385.1_ASM4055438v1_genomic.fna
# 134: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396395.1 -> GCF_038396395.1_ASM3839639v1_genomic.fna
# 135: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037543915.1 -> GCF_037543915.1_ASM3754391v1_genomic.fna
# 136: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037094625.1 -> GCF_037094625.1_ASM3709462v1_genomic.fna
# 137: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037542475.1 -> GCF_037542475.1_ASM3754247v1_genomic.fna
# 138: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_041004175.1 -> GCF_041004175.1_W170_genomic.fna
# 139: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037477985.1 -> GCF_037477985.1_ASM3747798v1_genomic.fna
# 140: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035666095.1 -> GCF_035666095.1_ASM3566609v1_genomic.fna
# 141: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036549195.1 -> GCF_036549195.1_ASM3654919v1_genomic.fna
# 142: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964051595.1 -> GCF_964051595.1_30859_5_11_genomic.fna
# 143: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964046695.1 -> GCF_964046695.1_30134_6_3_genomic.fna
# 144: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040436475.1 -> GCF_040436475.1_ASM4043647v1_genomic.fna
# 145: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396305.1 -> GCF_038396305.1_ASM3839630v1_genomic.fna
# 146: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040549745.1 -> GCF_040549745.1_ASM4054974v1_genomic.fna
# 147: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040930425.1 -> GCF_040930425.1_ASM4093042v1_genomic.fna
# 148: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_041021965.1 -> GCF_041021965.1_ASM4102196v1_genomic.fna
# 149: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037539565.1 -> GCF_037539565.1_ASM3753956v1_genomic.fna
# 150: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037528475.1 -> GCF_037528475.1_ASM3752847v1_genomic.fna
# 151: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039583315.1 -> GCF_039583315.1_ASM3958331v1_genomic.fna
# 152: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396375.1 -> GCF_038396375.1_ASM3839637v1_genomic.fna
# 153: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036287745.1 -> GCF_036287745.1_ASM3628774v1_genomic.fna
# 154: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040543515.1 -> GCF_040543515.1_ASM4054351v1_genomic.fna
# 155: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884485.1 -> GCF_036884485.1_ASM3688448v1_genomic.fna
# 156: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035621835.1 -> GCF_035621835.1_ASM3562183v1_genomic.fna
# 157: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036287705.1 -> GCF_036287705.1_ASM3628770v1_genomic.fna
# 158: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964054465.1 -> GCF_964054465.1_30821_1_330_genomic.fna
# 159: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040552425.1 -> GCF_040552425.1_ASM4055242v1_genomic.fna
# 160: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036713675.1 -> GCF_036713675.1_ASM3671367v2_genomic.fna
# 161: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035581925.1 -> GCF_035581925.1_ASM3558192v1_genomic.fna
# 162: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035582475.1 -> GCF_035582475.1_ASM3558247v1_genomic.fna
# 163: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035621815.1 -> GCF_035621815.1_ASM3562181v1_genomic.fna
# 164: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964039395.1 -> GCF_964039395.1_30348_1_195_genomic.fna
# 165: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040790915.1 -> GCF_040790915.1_ASM4079091v1_genomic.fna
# 166: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039912305.1 -> GCF_039912305.1_ASM3991230v1_genomic.fna
# 167: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035621095.1 -> GCF_035621095.1_ASM3562109v1_genomic.fna
# 168: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040529125.1 -> GCF_040529125.1_ASM4052912v1_genomic.fna
# 169: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964056585.1 -> GCF_964056585.1_30859_5_62_genomic.fna
# 170: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_026341465.2 -> GCF_026341465.2_ASM2634146v2_genomic.fna
# 171: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964051065.1 -> GCF_964051065.1_30602_1_64_genomic.fna
# 172: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964052415.1 -> GCF_964052415.1_30821_1_117_genomic.fna
# 173: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964052815.1 -> GCF_964052815.1_30224_1_48_genomic.fna
# 174: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884545.1 -> GCF_036884545.1_ASM3688454v1_genomic.fna
# 175: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964054525.1 -> GCF_964054525.1_30821_1_274_genomic.fna
# 176: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037546845.1 -> GCF_037546845.1_ASM3754684v1_genomic.fna
# 177: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040250335.1 -> GCF_040250335.1_ASM4025033v1_genomic.fna
# 178: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040500385.1 -> GCF_040500385.1_ASM4050038v1_genomic.fna
# 179: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037541525.1 -> GCF_037541525.1_ASM3754152v1_genomic.fna
# 180: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037094525.1 -> GCF_037094525.1_ASM3709452v1_genomic.fna
# 181: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964054945.1 -> GCF_964054945.1_30859_5_12_genomic.fna
# 182: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035974155.1 -> GCF_035974155.1_ASM3597415v1_genomic.fna
# 183: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040735505.1 -> GCF_040735505.1_ASM4073550v1_genomic.fna
# 184: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040436815.1 -> GCF_040436815.1_ASM4043681v1_genomic.fna
# 185: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040550665.1 -> GCF_040550665.1_ASM4055066v1_genomic.fna
# 186: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_963575765.1 -> GCF_963575765.1_GENOMIC21-003_genomic.fna
# 187: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037081895.1 -> GCF_037081895.1_ASM3708189v1_genomic.fna
# 188: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040939515.1 -> GCF_040939515.1_ASM4093951v1_genomic.fna
# 189: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037039445.1 -> GCF_037039445.1_ASM3703944v1_genomic.fna
# 190: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035928085.1 -> GCF_035928085.1_ASM3592808v1_genomic.fna
# 191: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884395.1 -> GCF_036884395.1_ASM3688439v1_genomic.fna
# 192: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037571465.1 -> GCF_037571465.1_ASM3757146v1_genomic.fna
# 193: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964048515.1 -> GCF_964048515.1_30602_6_35_genomic.fna
# 194: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037287435.1 -> GCF_037287435.1_ASM3728743v1_genomic.fna
# 195: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_041021975.1 -> GCF_041021975.1_ASM4102197v1_genomic.fna
# 196: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037081995.1 -> GCF_037081995.1_ASM3708199v1_genomic.fna
# 197: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_034120885.1 -> GCF_034120885.1_ASM3412088v2_genomic.fna
# 198: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040234295.1 -> GCF_040234295.1_ASM4023429v1_genomic.fna
# 199: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036705585.1 -> GCF_036705585.1_ASM3670558v1_genomic.fna
# 200: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_041016875.1 -> GCF_041016875.1_ASM4101687v1_genomic.fna
# 201: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_020526825.2 -> GCF_020526825.2_ASM2052682v2_genomic.fna
# 202: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_041021985.1 -> GCF_041021985.1_ASM4102198v1_genomic.fna
# 203: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_020526765.2 -> GCF_020526765.2_ASM2052676v2_genomic.fna
# 204: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035609265.1 -> GCF_035609265.1_ASM3560926v1_genomic.fna
# 205: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040436705.1 -> GCF_040436705.1_ASM4043670v1_genomic.fna
# 206: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_008364465.2 -> GCF_008364465.2_ASM836446v2_genomic.fna
# 207: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037287565.1 -> GCF_037287565.1_ASM3728756v1_genomic.fna
# 208: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_963924185.1 -> GCF_963924185.1_ST38_1_FIN_genomic.fna
# 209: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037477995.1 -> GCF_037477995.1_ASM3747799v1_genomic.fna
# 210: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_034334925.2 -> GCF_034334925.2_ASM3433492v2_genomic.fna
# 211: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037101265.1 -> GCF_037101265.1_ASM3710126v1_genomic.fna
# 212: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037275385.1 -> GCF_037275385.1_ASM3727538v1_genomic.fna
# 213: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038627105.1 -> GCF_038627105.1_ASM3862710v2_genomic.fna
# 214: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036923325.1 -> GCF_036923325.1_STEC27_genomic.fna
# 215: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_019585545.2 -> GCF_019585545.2_STEC2_genomic.fna
# 216: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039914745.1 -> GCF_039914745.1_ASM3991474v1_genomic.fna
# 217: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040529145.1 -> GCF_040529145.1_ASM4052914v1_genomic.fna
# 218: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884365.1 -> GCF_036884365.1_ASM3688436v1_genomic.fna
# 219: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_034335725.2 -> GCF_034335725.2_ASM3433572v2_genomic.fna
# 220: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396555.1 -> GCF_038396555.1_ASM3839655v1_genomic.fna
# 221: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035666315.1 -> GCF_035666315.1_ASM3566631v1_genomic.fna
# 222: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040763055.1 -> GCF_040763055.1_ASM4076305v1_genomic.fna
# 223: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964049315.1 -> GCF_964049315.1_30224_1_333_genomic.fna
# 224: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037568285.1 -> GCF_037568285.1_ASM3756828v1_genomic.fna
# 225: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040803525.1 -> GCF_040803525.1_ASM4080352v1_genomic.fna
# 226: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_034336645.2 -> GCF_034336645.2_ASM3433664v2_genomic.fna
# 227: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037563415.1 -> GCF_037563415.1_ASM3756341v1_genomic.fna
# 228: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037572835.1 -> GCF_037572835.1_ASM3757283v1_genomic.fna
# 229: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037094605.1 -> GCF_037094605.1_ASM3709460v1_genomic.fna
# 230: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037622475.1 -> GCF_037622475.1_ASM3762247v1_genomic.fna
# 231: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884415.1 -> GCF_036884415.1_ASM3688441v1_genomic.fna
# 232: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040554455.1 -> GCF_040554455.1_ASM4055445v1_genomic.fna
# 233: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884445.1 -> GCF_036884445.1_ASM3688444v1_genomic.fna
# 234: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040549715.1 -> GCF_040549715.1_ASM4054971v1_genomic.fna
# 235: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396525.1 -> GCF_038396525.1_ASM3839652v1_genomic.fna
# 236: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040571365.1 -> GCF_040571365.1_ASM4057136v1_genomic.fna
# 237: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037575825.1 -> GCF_037575825.1_ASM3757582v1_genomic.fna
# 238: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035666355.1 -> GCF_035666355.1_ASM3566635v1_genomic.fna
# 239: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037569855.1 -> GCF_037569855.1_ASM3756985v1_genomic.fna
# 240: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040267625.1 -> GCF_040267625.1_MRSN124611_genomic.fna
# 241: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884785.1 -> GCF_036884785.1_ASM3688478v1_genomic.fna
# 242: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037560265.1 -> GCF_037560265.1_ASM3756026v1_genomic.fna
# 243: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964046945.1 -> GCF_964046945.1_30345_1_247_genomic.fna
# 244: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964052875.1 -> GCF_964052875.1_30859_5_21_genomic.fna
# 245: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396295.1 -> GCF_038396295.1_ASM3839629v1_genomic.fna
# 246: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037575085.1 -> GCF_037575085.1_ASM3757508v1_genomic.fna
# 247: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037227975.1 -> GCF_037227975.1_ASM3722797v1_genomic.fna
# 248: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037819775.1 -> GCF_037819775.1_ASM3781977v1_genomic.fna
# 249: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_041022005.1 -> GCF_041022005.1_ASM4102200v1_genomic.fna
# 250: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040549775.1 -> GCF_040549775.1_ASM4054977v1_genomic.fna
# 251: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039583285.1 -> GCF_039583285.1_ASM3958328v1_genomic.fna
# 252: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040267605.1 -> GCF_040267605.1_MRSN126096_genomic.fna
# 253: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036703555.1 -> GCF_036703555.1_ASM3670355v1_genomic.fna
# 254: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040801825.1 -> GCF_040801825.1_ASM4080182v1_genomic.fna
# 255: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396355.1 -> GCF_038396355.1_ASM3839635v1_genomic.fna
# 256: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884775.1 -> GCF_036884775.1_ASM3688477v1_genomic.fna
# 257: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038420165.1 -> GCF_038420165.1_ASM3842016v1_genomic.fna
# 258: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035974115.1 -> GCF_035974115.1_ASM3597411v1_genomic.fna
# 259: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039909435.1 -> GCF_039909435.1_ASM3990943v1_genomic.fna
# 260: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040536875.1 -> GCF_040536875.1_ASM4053687v1_genomic.fna
# 261: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964046665.1 -> GCF_964046665.1_30345_1_186_genomic.fna
# 262: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_031675475.1 -> GCF_031675475.1_ASM3167547v2_genomic.fna
# 263: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_034331185.1 -> GCF_034331185.1_ASM3433118v2_genomic.fna
# 264: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037081975.1 -> GCF_037081975.1_ASM3708197v1_genomic.fna
# 265: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037231045.1 -> GCF_037231045.1_ASM3723104v1_genomic.fna
# 266: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040544505.1 -> GCF_040544505.1_ASM4054450v1_genomic.fna
# 267: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037287945.1 -> GCF_037287945.1_ASM3728794v1_genomic.fna
# 268: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040267635.1 -> GCF_040267635.1_MRSN123636_genomic.fna
# 269: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964053165.1 -> GCF_964053165.1_30224_1_38_genomic.fna
# 270: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884425.1 -> GCF_036884425.1_ASM3688442v1_genomic.fna
# 271: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039583325.1 -> GCF_039583325.1_ASM3958332v1_genomic.fna
# 272: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040784905.1 -> GCF_040784905.1_ASM4078490v1_genomic.fna
# 273: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040267455.1 -> GCF_040267455.1_ASM4026745v1_genomic.fna
# 274: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039909355.1 -> GCF_039909355.1_ASM3990935v1_genomic.fna
# 275: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037094535.1 -> GCF_037094535.1_ASM3709453v1_genomic.fna
# 276: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037094585.1 -> GCF_037094585.1_ASM3709458v1_genomic.fna
# 277: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037752355.1 -> GCF_037752355.1_ASM3775235v1_genomic.fna
# 278: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040255065.1 -> GCF_040255065.1_ASM4025506v1_genomic.fna
# 279: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396315.1 -> GCF_038396315.1_ASM3839631v1_genomic.fna
# 280: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_041003625.1 -> GCF_041003625.1_W284_genomic.fna
# 281: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037557155.1 -> GCF_037557155.1_ASM3755715v1_genomic.fna
# 282: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037287475.1 -> GCF_037287475.1_ASM3728747v1_genomic.fna
# 283: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037938425.1 -> GCF_037938425.1_ASM3793842v1_genomic.fna
# 284: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036702575.1 -> GCF_036702575.1_ASM3670257v1_genomic.fna
# 285: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040436785.1 -> GCF_040436785.1_ASM4043678v1_genomic.fna
# 286: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037280805.1 -> GCF_037280805.1_ASM3728080v1_genomic.fna
# 287: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039909185.1 -> GCF_039909185.1_ASM3990918v1_genomic.fna
# 288: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964038705.1 -> GCF_964038705.1_30348_1_3_genomic.fna
# 289: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037287675.1 -> GCF_037287675.1_ASM3728767v1_genomic.fna
# 290: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040939555.1 -> GCF_040939555.1_ASM4093955v1_genomic.fna
# 291: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037566655.1 -> GCF_037566655.1_ASM3756665v1_genomic.fna
# 292: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884495.1 -> GCF_036884495.1_ASM3688449v1_genomic.fna
# 293: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964055375.1 -> GCF_964055375.1_30859_5_40_genomic.fna
# 294: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040500455.1 -> GCF_040500455.1_ASM4050045v1_genomic.fna
# 295: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964043575.1 -> GCF_964043575.1_30348_2_316_genomic.fna
# 296: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040529135.1 -> GCF_040529135.1_ASM4052913v1_genomic.fna
# 297: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037750835.1 -> GCF_037750835.1_ASM3775083v1_genomic.fna
# 298: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039725815.1 -> GCF_039725815.1_ASM3972581v1_genomic.fna
# 299: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039909815.1 -> GCF_039909815.1_ASM3990981v1_genomic.fna
# 300: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040436685.1 -> GCF_040436685.1_ASM4043668v1_genomic.fna
# 301: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038096125.1 -> GCF_038096125.1_ASM3809612v1_genomic.fna
# 302: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038627295.1 -> GCF_038627295.1_ASM3862729v2_genomic.fna
# 303: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_041006045.1 -> GCF_041006045.1_W4_genomic.fna
# 304: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964049545.1 -> GCF_964049545.1_30821_1_88_genomic.fna
# 305: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396485.1 -> GCF_038396485.1_ASM3839648v1_genomic.fna
# 306: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036222425.1 -> GCF_036222425.1_ASM3622242v1_genomic.fna
# 307: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037543765.1 -> GCF_037543765.1_ASM3754376v1_genomic.fna
# 308: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037094635.1 -> GCF_037094635.1_ASM3709463v1_genomic.fna
# 309: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038096085.1 -> GCF_038096085.1_ASM3809608v1_genomic.fna
# 310: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037126185.1 -> GCF_037126185.1_ASM3712618v1_genomic.fna
# 311: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040763135.1 -> GCF_040763135.1_ASM4076313v1_genomic.fna
# 312: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396535.1 -> GCF_038396535.1_ASM3839653v1_genomic.fna
# 313: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036704625.1 -> GCF_036704625.1_ASM3670462v1_genomic.fna
# 314: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964036945.1 -> GCF_964036945.1_30345_1_279_genomic.fna
# 315: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884375.1 -> GCF_036884375.1_ASM3688437v1_genomic.fna
# 316: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040551325.1 -> GCF_040551325.1_ASM4055132v1_genomic.fna
# 317: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037126325.1 -> GCF_037126325.1_ASM3712632v1_genomic.fna
# 318: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037280675.1 -> GCF_037280675.1_ASM3728067v1_genomic.fna
# 319: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_963575795.1 -> GCF_963575795.1_GENOMIC21-004_genomic.fna
# 320: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037094615.1 -> GCF_037094615.1_ASM3709461v1_genomic.fna
# 321: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037094575.1 -> GCF_037094575.1_ASM3709457v1_genomic.fna
# 322: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037286755.1 -> GCF_037286755.1_ASM3728675v1_genomic.fna
# 323: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036287645.1 -> GCF_036287645.1_ASM3628764v1_genomic.fna
# 324: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_020526845.2 -> GCF_020526845.2_ASM2052684v2_genomic.fna
# 325: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037623895.1 -> GCF_037623895.1_ASM3762389v1_genomic.fna
# 326: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964049805.1 -> GCF_964049805.1_30224_1_305_genomic.fna
# 327: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035973695.1 -> GCF_035973695.1_ASM3597369v1_genomic.fna
# 328: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964051515.1 -> GCF_964051515.1_30345_1_31_genomic.fna
# 329: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040745645.1 -> GCF_040745645.1_ASM4074564v1_genomic.fna
# 330: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964036705.1 -> GCF_964036705.1_30602_1_109_genomic.fna
# 331: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039679135.1 -> GCF_039679135.1_ASM3967913v1_genomic.fna
# 332: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_963924205.1 -> GCF_963924205.1_ST38_3_FIN_genomic.fna
# 333: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037277815.1 -> GCF_037277815.1_ASM3727781v1_genomic.fna
# 334: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_041006255.1 -> GCF_041006255.1_ASM4100625v1_genomic.fna
# 335: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037939535.1 -> GCF_037939535.1_ASM3793953v1_genomic.fna
# 336: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_020526805.2 -> GCF_020526805.2_ASM2052680v2_genomic.fna
# 337: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_963924195.1 -> GCF_963924195.1_ST38_2_FIN_genomic.fna
# 338: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035621595.1 -> GCF_035621595.1_ASM3562159v1_genomic.fna
# 339: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040500465.1 -> GCF_040500465.1_ASM4050046v1_genomic.fna
# 340: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036870985.1 -> GCF_036870985.1_ASM3687098v1_genomic.fna
# 341: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040545955.1 -> GCF_040545955.1_ASM4054595v1_genomic.fna
# 342: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037561805.1 -> GCF_037561805.1_ASM3756180v1_genomic.fna
# 343: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037759535.1 -> GCF_037759535.1_ASM3775953v1_genomic.fna
# 344: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964050955.1 -> GCF_964050955.1_30859_5_29_genomic.fna
# 345: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037094565.1 -> GCF_037094565.1_ASM3709456v1_genomic.fna
# 346: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964041535.1 -> GCF_964041535.1_30348_1_89_genomic.fna
# 347: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039911655.1 -> GCF_039911655.1_ASM3991165v1_genomic.fna
# 348: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_041022015.1 -> GCF_041022015.1_ASM4102201v1_genomic.fna
# 349: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037953405.1 -> GCF_037953405.1_ASM3795340v1_genomic.fna
# 350: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036287665.1 -> GCF_036287665.1_ASM3628766v1_genomic.fna
# 351: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040250355.1 -> GCF_040250355.1_ASM4025035v1_genomic.fna
# 352: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040616285.1 -> GCF_040616285.1_EC554-PBR_genomic.fna
# 353: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040571355.1 -> GCF_040571355.1_ASM4057135v1_genomic.fna
# 354: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037529465.1 -> GCF_037529465.1_ASM3752946v1_genomic.fna
# 355: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040551085.1 -> GCF_040551085.1_ASM4055108v1_genomic.fna
# 356: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037269235.1 -> GCF_037269235.1_ASM3726923v1_genomic.fna
# 357: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039926885.1 -> GCF_039926885.1_ASM3992688v1_genomic.fna
# 358: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040215525.1 -> GCF_040215525.1_ASM4021552v1_genomic.fna
# 359: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040030455.2 -> GCF_040030455.2_ASM4003045v1_genomic.fna
# 360: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_024199045.2 -> GCF_024199045.2_ASM2419904v2_genomic.fna
# 361: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_034339465.2 -> GCF_034339465.2_ASM3433946v2_genomic.fna
# 362: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964038895.1 -> GCF_964038895.1_30345_1_335_genomic.fna
# 363: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037288615.1 -> GCF_037288615.1_ASM3728861v1_genomic.fna
# 364: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396335.1 -> GCF_038396335.1_ASM3839633v1_genomic.fna
# 365: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037094545.1 -> GCF_037094545.1_ASM3709454v1_genomic.fna
# 366: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396515.1 -> GCF_038396515.1_ASM3839651v1_genomic.fna
# 367: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040267575.1 -> GCF_040267575.1_MRSN914033_genomic.fna
# 368: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037287395.1 -> GCF_037287395.1_ASM3728739v1_genomic.fna
# 369: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037113475.1 -> GCF_037113475.1_ASM3711347v1_genomic.fna
# 370: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039909535.1 -> GCF_039909535.1_ASM3990953v1_genomic.fna
# 371: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036419615.1 -> GCF_036419615.1_ASM3641961v1_genomic.fna
# 372: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964055715.1 -> GCF_964055715.1_30859_5_96_genomic.fna
# 373: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037574055.1 -> GCF_037574055.1_ASM3757405v1_genomic.fna
# 374: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_008364515.2 -> GCF_008364515.2_ASM836451v2_genomic.fna
# 375: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_041004315.1 -> GCF_041004315.1_W137_genomic.fna
# 376: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_041014865.1 -> GCF_041014865.1_Genome_assembly_GPTB0038_genomic.fna
# 377: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396365.1 -> GCF_038396365.1_ASM3839636v1_genomic.fna
# 378: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_041005995.1 -> GCF_041005995.1_W21_genomic.fna
# 379: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396695.1 -> GCF_038396695.1_ASM3839669v1_genomic.fna
# 380: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_008364455.2 -> GCF_008364455.2_ASM836445v2_genomic.fna
# 381: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038430275.1 -> GCF_038430275.1_ASM3843027v1_genomic.fna
# 382: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039645365.1 -> GCF_039645365.1_ASM3964536v1_genomic.fna
# 383: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040735635.1 -> GCF_040735635.1_ASM4073563v1_genomic.fna
# 384: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396565.1 -> GCF_038396565.1_ASM3839656v1_genomic.fna
# Done

# %%
time_array = []
max_resident_size_array = []

for file_path in directories:
    if not os.path.isfile(file_path + "/time.txt"):
        print(f"The file at {file_path} does not exist.")
        continue

    try:
        with open(file_path + "/time.txt", 'r') as file:
            found_time = False
            found_max_res = False

            for line in file:
                if not found_time:
                    time_match = re.search(r'User time \(seconds\): ([\d.]+)', line)
                    if time_match:
                        time_taken = time_match.group(1)
                        time_array.append(float(time_taken))
                        found_time = True

                if not found_max_res:
                    max_res_match = re.search(r'Maximum resident set size \(kbytes\): (\d+)', line)
                    if max_res_match:
                        max_resident_size = max_res_match.group(1)
                        max_resident_size_array.append(int(max_resident_size))
                        found_max_res = True

                if found_time and found_max_res:
                    break

            if not found_time:
                print(f"No simulation time found in the file: {file_path}")
            if not found_max_res:
                print(f"No maximum resident set size found in the file: {file_path}")
                
    except Exception as e:
        print(f"An error occurred while processing the file {file_path}: {e}")

print(f"Time array: {len(time_array)}")
print(f"Maximum resident size array: {len(max_resident_size_array)}")

print(f"T: {time_array[0]}, M: {max_resident_size_array[0]}")
# Out:
# Time array: 384
# Maximum resident size array: 384
# T: 4.04, M: 401652

# %%
# Array to hold file sizes
file_sizes = []

for file_path in original_genomes:
    try:
        # Get the file size
        file_size = os.path.getsize(file_path)
        # Append the file size to the array
        file_sizes.append(file_size)
    except OSError as e:
        # If there's an error (e.g., file doesn't exist), append None and print an error message
        file_sizes.append(None)
        print(f"Error accessing file {file_path}: {e}")

# Print the array with file sizes
print("File sizes:", len(file_sizes))
# Out:
# File sizes: 384

# %%
# Plotting time against genome size
# Convert file paths to a simple numeric index for x-axis
x = file_sizes
y = time_array

plt.figure(figsize=(6, 4))  # Set the figure size (width, height)
plt.scatter(x, y)
plt.title('SimuG Same Species: File Sizes vs. Simulation Time')
plt.xlabel('File Size (bytes)')
plt.ylabel('Simulation Time (seconds)')
plt.gca().yaxis.set_major_formatter(ticker.FormatStrFormatter('%.1f'))
plt.show()

# %%
# Plotting time against genome size
# Convert file paths to a simple numeric index for x-axis
x = file_sizes
y = max_resident_size_array

plt.figure(figsize=(6, 4))  # Set the figure size (width, height)
plt.scatter(x, y)
plt.title('SimuG Same Species: File Sizes vs. Maximum Resident Size')
plt.xlabel('File Size (bytes)')
plt.ylabel('Resident Size (bytes)')
plt.show()

# %%
# Get paths of new genomes
# See if there has been a 5% change in each, get length of orginal, length of change and difference value between them.ls
new_genomes = []
end_pattern = ".fa"
mod_patterns = "0.05"

# Traverse the directory tree
for root, dirs, files in os.walk(start_directory):
    for file in files:
        if end_pattern in file and mod_patterns in file:
            new_genomes.append(str(root) + "/" + str(file))


print(f"Done: {len(new_genomes)}")

if len(new_genomes) != len(directories):
    print(f"Failed: {len(directories) - len(new_genomes)}")
# Out:
# Done: 383
# Failed: 1

# %%
# List to store values from 'a' that are not in 'b'
new_dir = directories.copy()
locations = []

# Iterate through each element in 'a'
index = 0
for item_a in directories:
    match_found = False
    # Check if any element in 'b' contains the current element in 'a'
    for item_b in new_genomes:
        if item_a in item_b:
            match_found = True
            break
    # If no match found, add to non_matching_values
    if not match_found:
        new_dir.remove(item_a)
        locations.append(index)
    index = index + 1
        
# Print the non-matching values
print(len(new_dir))
print(len(directories))
print(len(locations))

for loc in locations:
    print(loc)
# Out:
# 383
# 384
# 1
# 150

# %%
# Make full path of original files
original_genomes = []
offset = 0
for i in range(len(new_dir)):
    if i + offset in locations:
        for loc in locations:
            loc + 1
        offset = offset + 1
    file_location = new_dir[i] + "/" + file_names[i + offset]
    original_genomes.append(file_location)

print(f"Done: {len(original_genomes)}")
# for j in range(175,185):
#     print(f"{j}, {original_genomes[j]}")
# Out:
# Done: 383

# %%
# Running ANI Tests
for i in range(len(new_genomes)):
    file_paths = [original_genomes[i], new_genomes[i]]

    # Process each file in the file_paths list
    command = f'cd {new_dir[i]} && /opt/FastANI-v1.34/fastANI -r {original_genomes[i]} -q {new_genomes[i]} -o {new_dir[i]}/0.05_fastani.txt'
    try:
        # Run the command in the shell with a timeout of 3 minutes
        result = subprocess.run(command, shell=True, timeout=3*60, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL, universal_newlines=True)

        # Print stderr output
        if result.stderr:
            print(result.stderr)
                
    except subprocess.TimeoutExpired as e:
        print(f"Command timed out: {e}")
    except Exception as e:
        print(f"An error occurred: {e}")

print("Done")
# Out:
# Done

# %%
# Read ANI test results
# Arrays to store ANI values and other related information
ani_values_array = []
index = 0

for file_path in new_dir:
    #if check[index] == 1:
    if 1 == 1:
        print(f"{index}: {file_path}")
        fastani_file = os.path.join(file_path, "0.05_fastani.txt")
        if not os.path.isfile(fastani_file):
            print(f"The file at {fastani_file} does not exist.")
            continue
    
        try:
            with open(fastani_file, 'r') as file:
                for line in file:
                    parts = line.strip().split('\t')
                    if len(parts) >= 3:
                        try:
                            ani_value = float(parts[2])
                            print(ani_value)
                            ani_values_array.append(ani_value)
                        except ValueError:
                            print(f"Could not convert ANI value to float: {parts[2]}")
                    
        except Exception as e:
            print(f"An error occurred while processing the file {fastani_file}: {e}")
    index += 1
# Out:
# 0: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884635.1
# 94.4093
# 1: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884625.1
# 94.4072
# 2: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039912475.1
# 94.3937
# 3: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036923505.1
# 94.419
# 4: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037914955.1
# 94.4164
# 5: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039912655.1
# 94.412
# 6: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039583295.1
# 94.42
# 7: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964053065.1
# 94.3979
# 8: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040267585.1
# 94.3963
# 9: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884765.1
# 94.4221
# 10: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035974135.1
# 94.3981
# 11: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040267555.1
# 94.4144
# 12: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040834075.1
# 94.4101
# 13: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040551675.1
# 94.418
# 14: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040267445.1
# 94.3986
# 15: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037555585.1
# 94.4084
# 16: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037760445.1
# 94.419
# 17: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039909425.1
# 94.4225
# 18: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036818325.1
# 94.4164
# 19: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039583305.1
# 94.4181
# 20: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964047955.1
# 94.4064
# 21: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884355.1
# 94.4116
# 22: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040215555.1
# 94.3963
# 23: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884645.1
# 94.3946
# 24: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035621115.1
# 94.3827
# 25: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_030939765.1
# 94.4183
# 26: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039909525.1
# 94.4306
# 27: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040105125.1
# 94.4161
# 28: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964045445.1
# 94.4308
# 29: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039654195.1
# 94.4058
# 30: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040703075.1
# 94.4223
# 31: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_041021995.1
# 94.4171
# 32: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964043425.1
# 94.4063
# 33: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037584545.1
# 94.3957
# 34: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037525705.1
# 94.4028
# 35: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_034338325.2
# 94.4088
# 36: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039909515.1
# 94.4096
# 37: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037575275.1
# 94.4307
# 38: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037573545.1
# 94.4017
# 39: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037558665.1
# 94.4011
# 40: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038248495.1
# 94.4089
# 41: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035557515.1
# 94.3994
# 42: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035972895.1
# 94.4067
# 43: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_041005895.1
# 94.4322
# 44: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040543495.1
# 94.4265
# 45: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035974095.1
# 94.4269
# 46: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036785845.1
# 94.4167
# 47: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040959095.1
# 94.3981
# 48: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037756885.1
# 94.4115
# 49: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040550895.1
# 94.3997
# 50: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_019585785.2
# 94.403
# 51: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038096105.1
# 94.4183
# 52: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040783495.1
# 94.4225
# 53: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036702845.1
# 94.3999
# 54: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040438625.1
# 94.4205
# 55: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396505.1
# 94.4062
# 56: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037890705.1
# 94.4151
# 57: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037576255.1
# 94.4089
# 58: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035621615.1
# 94.4026
# 59: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037273335.1
# 94.4314
# 60: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040268295.1
# 94.4418
# 61: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396495.1
# 94.3923
# 62: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037081875.1
# 94.4083
# 63: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_029870635.2
# 94.4058
# 64: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039851985.1
# 94.4445
# 65: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040267565.1
# 94.4281
# 66: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_041004245.1
# 94.4179
# 67: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040267615.1
# 94.4073
# 68: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884535.1
# 94.4101
# 69: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037287445.1
# 94.3996
# 70: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037744325.1
# 94.4162
# 71: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040267595.1
# 94.3969
# 72: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884615.1
# 94.4162
# 73: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037101415.1
# 94.4371
# 74: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884805.1
# 94.4291
# 75: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037082015.1
# 94.4181
# 76: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964049475.1
# 94.4152
# 77: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036287685.1
# 94.4238
# 78: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037526635.1
# 94.4229
# 79: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037540695.1
# 94.4055
# 80: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884405.1
# 94.4178
# 81: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036452055.1
# 94.4093
# 82: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036287725.1
# 94.4259
# 83: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037565025.1
# 94.4067
# 84: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964049185.1
# 94.4116
# 85: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_020526785.2
# 94.4288
# 86: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884435.1
# 94.4041
# 87: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964046655.1
# 94.4181
# 88: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884755.1
# 94.3944
# 89: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040551235.1
# 94.4097
# 90: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037482115.1
# 94.399
# 91: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036687395.1
# 94.4117
# 92: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040931675.1
# 94.4077
# 93: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037549885.1
# 94.4099
# 94: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964048075.1
# 94.4192
# 95: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_019585465.2
# 94.4003
# 96: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037081985.1
# 94.4011
# 97: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037287415.1
# 94.396
# 98: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040543435.1
# 94.4378
# 99: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040555885.1
# 94.4255
# 100: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_034337405.2
# 94.4006
# 101: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884385.1
# 94.4004
# 102: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040267775.1
# 94.4075
# 103: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040549815.1
# 94.4248
# 104: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_008364435.2
# 94.4184
# 105: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037094505.1
# 94.4038
# 106: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036287825.1
# 94.4372
# 107: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037527585.1
# 94.3912
# 108: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036362825.1
# 94.4131
# 109: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037094515.1
# 94.3946
# 110: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037287455.1
# 94.428
# 111: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037100245.1
# 94.4281
# 112: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037225585.1
# 94.4074
# 113: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_020526745.2
# 94.4195
# 114: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037553545.1
# 94.4245
# 115: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964038595.1
# 94.4189
# 116: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036923335.1
# 94.4177
# 117: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_020526725.2
# 94.399
# 118: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884795.1
# 94.4183
# 119: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037094555.1
# 94.4036
# 120: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396545.1
# 94.3856
# 121: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038096115.1
# 94.4246
# 122: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396705.1
# 94.4043
# 123: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964054695.1
# 94.3983
# 124: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038627065.1
# 94.3893
# 125: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039555125.1
# 94.4175
# 126: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037553955.1
# 94.4109
# 127: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040543575.1
# 94.4191
# 128: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035621515.1
# 94.4051
# 129: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964040665.1
# 94.398
# 130: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037920625.1
# 94.4157
# 131: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039912505.1
# 94.428
# 132: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040554385.1
# 94.3958
# 133: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396395.1
# 94.4261
# 134: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037543915.1
# 94.4072
# 135: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037094625.1
# 94.4055
# 136: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037542475.1
# 94.421
# 137: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_041004175.1
# 94.4121
# 138: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037477985.1
# 94.397
# 139: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035666095.1
# 94.4189
# 140: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036549195.1
# 94.4049
# 141: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964051595.1
# 94.4244
# 142: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964046695.1
# 94.4172
# 143: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040436475.1
# 94.4179
# 144: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396305.1
# 94.4175
# 145: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040549745.1
# 94.421
# 146: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040930425.1
# 94.3999
# 147: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_041021965.1
# 94.3882
# 148: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037539565.1
# 94.3855
# 149: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037528475.1
# 94.3972
# 150: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396375.1
# 94.413
# 151: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036287745.1
# 94.4275
# 152: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040543515.1
# 94.4107
# 153: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884485.1
# 94.4143
# 154: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035621835.1
# 94.4098
# 155: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036287705.1
# 94.4273
# 156: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964054465.1
# 94.4199
# 157: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040552425.1
# 94.4155
# 158: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036713675.1
# 94.407
# 159: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035581925.1
# 94.4231
# 160: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035582475.1
# 94.3928
# 161: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035621815.1
# 94.4226
# 162: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964039395.1
# 94.426
# 163: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040790915.1
# 94.3962
# 164: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039912305.1
# 94.4021
# 165: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035621095.1
# 94.4263
# 166: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040529125.1
# 94.4156
# 167: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964056585.1
# 94.4063
# 168: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_026341465.2
# 94.4043
# 169: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964051065.1
# 94.412
# 170: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964052415.1
# 94.4112
# 171: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964052815.1
# 94.4031
# 172: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884545.1
# 94.4052
# 173: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964054525.1
# 94.4208
# 174: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037546845.1
# 94.4176
# 175: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040250335.1
# 94.4128
# 176: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040500385.1
# 94.3928
# 177: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037541525.1
# 94.427
# 178: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037094525.1
# 94.4178
# 179: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964054945.1
# 94.3994
# 180: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035974155.1
# 94.4207
# 181: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040735505.1
# 94.4195
# 182: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040436815.1
# 94.4058
# 183: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040550665.1
# 94.4058
# 184: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_963575765.1
# 94.4102
# 185: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037081895.1
# 94.411
# 186: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040939515.1
# 94.4214
# 187: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037039445.1
# 94.4098
# 188: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035928085.1
# 94.3885
# 189: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884395.1
# 94.421
# 190: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037571465.1
# 94.4113
# 191: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964048515.1
# 94.4149
# 192: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037287435.1
# 94.4283
# 193: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_041021975.1
# 94.4358
# 194: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037081995.1
# 94.4067
# 195: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_034120885.1
# 94.4027
# 196: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040234295.1
# 94.4315
# 197: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036705585.1
# 94.4197
# 198: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_041016875.1
# 94.407
# 199: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_020526825.2
# 94.4176
# 200: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_041021985.1
# 94.4253
# 201: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_020526765.2
# 94.408
# 202: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035609265.1
# 94.4266
# 203: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040436705.1
# 94.4231
# 204: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_008364465.2
# 94.4003
# 205: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037287565.1
# 94.4103
# 206: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_963924185.1
# 94.4189
# 207: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037477995.1
# 94.4153
# 208: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_034334925.2
# 94.4344
# 209: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037101265.1
# 94.4059
# 210: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037275385.1
# 94.4475
# 211: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038627105.1
# 94.428
# 212: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036923325.1
# 94.4225
# 213: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_019585545.2
# 94.3845
# 214: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039914745.1
# 94.4049
# 215: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040529145.1
# 94.4208
# 216: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884365.1
# 94.402
# 217: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_034335725.2
# 94.3933
# 218: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396555.1
# 94.4038
# 219: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035666315.1
# 94.3939
# 220: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040763055.1
# 94.4316
# 221: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964049315.1
# 94.4106
# 222: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037568285.1
# 94.4106
# 223: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040803525.1
# 94.4196
# 224: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_034336645.2
# 94.4123
# 225: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037563415.1
# 94.4109
# 226: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037572835.1
# 94.4149
# 227: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037094605.1
# 94.4124
# 228: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037622475.1
# 94.4111
# 229: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884415.1
# 94.3946
# 230: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040554455.1
# 94.4013
# 231: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884445.1
# 94.4275
# 232: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040549715.1
# 94.4073
# 233: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396525.1
# 94.4001
# 234: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040571365.1
# 94.4221
# 235: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037575825.1
# 94.4447
# 236: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035666355.1
# 94.399
# 237: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037569855.1
# 94.4164
# 238: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040267625.1
# 94.4132
# 239: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884785.1
# 94.3877
# 240: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037560265.1
# 94.4184
# 241: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964046945.1
# 94.3971
# 242: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964052875.1
# 94.4203
# 243: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396295.1
# 94.4473
# 244: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037575085.1
# 94.409
# 245: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037227975.1
# 94.4008
# 246: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037819775.1
# 94.4079
# 247: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_041022005.1
# 94.4151
# 248: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040549775.1
# 94.4209
# 249: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039583285.1
# 94.3859
# 250: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040267605.1
# 94.4162
# 251: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036703555.1
# 94.4525
# 252: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040801825.1
# 94.3775
# 253: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396355.1
# 94.422
# 254: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884775.1
# 94.419
# 255: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038420165.1
# 94.4183
# 256: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035974115.1
# 94.4229
# 257: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039909435.1
# 94.395
# 258: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040536875.1
# 94.4174
# 259: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964046665.1
# 94.4206
# 260: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_031675475.1
# 94.4087
# 261: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_034331185.1
# 94.4311
# 262: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037081975.1
# 94.4146
# 263: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037231045.1
# 94.3985
# 264: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040544505.1
# 94.4199
# 265: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037287945.1
# 94.4083
# 266: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040267635.1
# 94.4259
# 267: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964053165.1
# 94.402
# 268: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884425.1
# 94.4053
# 269: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039583325.1
# 94.4098
# 270: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040784905.1
# 94.415
# 271: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040267455.1
# 94.4064
# 272: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039909355.1
# 94.3957
# 273: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037094535.1
# 94.4183
# 274: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037094585.1
# 94.3994
# 275: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037752355.1
# 94.4079
# 276: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040255065.1
# 94.4142
# 277: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396315.1
# 94.4107
# 278: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_041003625.1
# 94.4084
# 279: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037557155.1
# 94.4126
# 280: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037287475.1
# 94.4114
# 281: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037938425.1
# 94.4024
# 282: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036702575.1
# 94.4182
# 283: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040436785.1
# 94.4261
# 284: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037280805.1
# 94.3911
# 285: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039909185.1
# 94.398
# 286: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964038705.1
# 94.4165
# 287: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037287675.1
# 94.4139
# 288: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040939555.1
# 94.3978
# 289: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037566655.1
# 94.3999
# 290: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884495.1
# 94.4105
# 291: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964055375.1
# 94.4124
# 292: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040500455.1
# 94.4156
# 293: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964043575.1
# 94.3853
# 294: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040529135.1
# 94.4201
# 295: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037750835.1
# 94.4195
# 296: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039725815.1
# 94.4003
# 297: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039909815.1
# 94.4168
# 298: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040436685.1
# 94.4015
# 299: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038096125.1
# 94.4072
# 300: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038627295.1
# 94.4332
# 301: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_041006045.1
# 94.4259
# 302: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964049545.1
# 94.4197
# 303: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396485.1
# 94.4136
# 304: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036222425.1
# 94.4125
# 305: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037543765.1
# 94.4092
# 306: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037094635.1
# 94.4601
# 307: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038096085.1
# 94.4001
# 308: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037126185.1
# 94.4133
# 309: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040763135.1
# 94.4108
# 310: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396535.1
# 94.4053
# 311: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036704625.1
# 94.4128
# 312: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964036945.1
# 94.4125
# 313: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884375.1
# 94.4204
# 314: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040551325.1
# 94.412
# 315: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037126325.1
# 94.4219
# 316: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037280675.1
# 94.4142
# 317: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_963575795.1
# 94.4187
# 318: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037094615.1
# 94.4487
# 319: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037094575.1
# 94.4103
# 320: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037286755.1
# 94.4367
# 321: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036287645.1
# 94.4103
# 322: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_020526845.2
# 94.3866
# 323: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037623895.1
# 94.4164
# 324: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964049805.1
# 94.4136
# 325: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035973695.1
# 94.4004
# 326: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964051515.1
# 94.4182
# 327: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040745645.1
# 94.4171
# 328: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964036705.1
# 94.3907
# 329: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039679135.1
# 94.4219
# 330: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_963924205.1
# 94.4155
# 331: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037277815.1
# 94.4387
# 332: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_041006255.1
# 94.4097
# 333: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037939535.1
# 94.4221
# 334: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_020526805.2
# 94.4214
# 335: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_963924195.1
# 94.4214
# 336: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_035621595.1
# 94.3955
# 337: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040500465.1
# 94.4043
# 338: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036870985.1
# 94.3955
# 339: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040545955.1
# 94.4063
# 340: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037561805.1
# 94.4297
# 341: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037759535.1
# 94.4144
# 342: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964050955.1
# 94.3954
# 343: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037094565.1
# 94.4082
# 344: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964041535.1
# 94.4376
# 345: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039911655.1
# 94.4258
# 346: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_041022015.1
# 94.4347
# 347: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037953405.1
# 94.423
# 348: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036287665.1
# 94.4202
# 349: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040250355.1
# 94.417
# 350: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040616285.1
# 94.4044
# 351: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040571355.1
# 94.4237
# 352: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037529465.1
# 94.4345
# 353: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040551085.1
# 94.4247
# 354: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037269235.1
# 94.4132
# 355: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039926885.1
# 94.4112
# 356: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040215525.1
# 94.3997
# 357: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040030455.2
# 94.3989
# 358: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_024199045.2
# 94.4165
# 359: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_034339465.2
# 94.4044
# 360: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964038895.1
# 94.3969
# 361: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037288615.1
# 94.4195
# 362: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396335.1
# 94.3982
# 363: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037094545.1
# 94.3988
# 364: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396515.1
# 94.4152
# 365: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040267575.1
# 94.4115
# 366: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037287395.1
# 94.4124
# 367: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037113475.1
# 94.4303
# 368: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039909535.1
# 94.3921
# 369: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036419615.1
# 94.4004
# 370: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964055715.1
# 94.4213
# 371: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037574055.1
# 94.4333
# 372: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_008364515.2
# 94.4212
# 373: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_041004315.1
# 94.4111
# 374: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_041014865.1
# 94.4136
# 375: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396365.1
# 94.4018
# 376: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_041005995.1
# 94.3908
# 377: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396695.1
# 94.418
# 378: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_008364455.2
# 94.4037
# 379: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038430275.1
# 94.4271
# 380: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039645365.1
# 94.4304
# 381: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040735635.1
# 94.428
# 382: /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_038396565.1
# 94.4062

# %%
# Plotting time against genome size
# Convert file paths to a simple numeric index for x-axis
x = file_sizes[0:len(ani_values_array)]
y = ani_values_array

plt.figure(figsize=(6, 4))  # Set the figure size (width, height)
plt.scatter(x, y)
plt.title('SimuG Simulator Same Species: File Sizes vs. ANI Score (5% SNP Rate)')
plt.xlabel('File Size (bytes)')
plt.ylabel('ANI score (%)')
plt.show()

# %%
# Your existing data
x = file_sizes
y = ani_values_array

plt.figure(figsize=(6, 4))  # Set the figure size (width, height)

# Create a histogram of the ANI scores
plt.hist(y, bins=100, edgecolor='black')  # Adjust the number of bins as needed
plt.title('simuG Simulator Same Species: Distribution of ANI Scores (5% SNP Rate)')
plt.xlabel('ANI score (%)')
plt.ylabel('Frequency')
plt.show()

# %%
# Calculate statistics for ANI scores
y = numpy.array(ani_values_array)
ani_mean = numpy.mean(y)
ani_median = numpy.median(y)
ani_std = numpy.std(y)
ani_min = numpy.min(y)
ani_max = numpy.max(y)
ani_range = ani_max - ani_min
print("ANI Scores Statistics:")
print(f"Mean: {ani_mean}")
print(f"Median: {ani_median}")
print(f"Standard Deviation: {ani_std}")
print(f"Min: {ani_min}")
print(f"Max: {ani_max}")
print(f"Range: {ani_range}")
# Out:
# ANI Scores Statistics:
# Mean: 94.4126046997389
# Median: 94.4124
# Standard Deviation: 0.012650329621446924
# Min: 94.3775
# Max: 94.4601
# Range: 0.08259999999999934

# %%
# Create simulations at different rates
index = 0
rate = [0.01,0.02,0.03,0.04,0.06,0.07,0.08,0.09,0.10] # Already have done 0.05
for SNP_rate in rate:
    if new_dir and file_names:
        count = 0  # Counter for directories processed
        for first_directory, first_fna_file in zip(new_dir, file_names):
            if count >= 10:  # Check if 10 directories have been processed
                break

            index = index + 1
            print(f'{index}: {SNP_rate}) {first_directory} -> {first_fna_file}')

            # Build the command to change directory and show the first 10 lines of the .fna file
            command = f'cd {first_directory} && (/usr/bin/time -v mutation-simulator {first_fna_file} args -sn {SNP_rate} && mv $(find . -name "*.fna" | grep -vi "_gen" | grep -vi "SNP") SNP_{SNP_rate}_{first_fna_file} && mv $(find . -name "*.fna.fai" | grep -vi "SNP") SNP_{SNP_rate}_{first_fna_file}.fai) > stats.txt 2>&1'

            try:
                # Run the command in the shell with a timeout of 3 minutes
                result = subprocess.run(command, shell=True, timeout=3*60, stderr=subprocess.PIPE, universal_newlines=True)

                # Print stderr output
                if result.stderr:
                    print(result.stderr)
                
            except subprocess.TimeoutExpired as e:
                print(f"Command timed out: {e}")
            except Exception as e:
                print(f"An error occurred: {e}")

            count += 1  # Increment the counter after processing a directory
    else:
        print("No .fna files found.")
print("Done")
# Out:
# 1: 0.01) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884635.1 -> GCF_036884635.1_ASM3688463v1_genomic.fna
# 2: 0.01) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884625.1 -> GCF_036884625.1_ASM3688462v1_genomic.fna
# 3: 0.01) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039912475.1 -> GCF_039912475.1_ASM3991247v1_genomic.fna
# 4: 0.01) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036923505.1 -> GCF_036923505.1_STEC28_genomic.fna
# 5: 0.01) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037914955.1 -> GCF_037914955.1_pKPC_NDMdeltaNDM_genomic.fna
# 6: 0.01) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039912655.1 -> GCF_039912655.1_ASM3991265v1_genomic.fna
# 7: 0.01) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039583295.1 -> GCF_039583295.1_ASM3958329v1_genomic.fna
# 8: 0.01) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964053065.1 -> GCF_964053065.1_30859_5_287_genomic.fna
# 9: 0.01) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040267585.1 -> GCF_040267585.1_MRSN129130_genomic.fna
# 10: 0.01) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884765.1 -> GCF_036884765.1_ASM3688476v1_genomic.fna
# 11: 0.02) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884635.1 -> GCF_036884635.1_ASM3688463v1_genomic.fna
# 12: 0.02) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884625.1 -> GCF_036884625.1_ASM3688462v1_genomic.fna
# 13: 0.02) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039912475.1 -> GCF_039912475.1_ASM3991247v1_genomic.fna
# 14: 0.02) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036923505.1 -> GCF_036923505.1_STEC28_genomic.fna
# 15: 0.02) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037914955.1 -> GCF_037914955.1_pKPC_NDMdeltaNDM_genomic.fna
# 16: 0.02) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039912655.1 -> GCF_039912655.1_ASM3991265v1_genomic.fna
# 17: 0.02) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039583295.1 -> GCF_039583295.1_ASM3958329v1_genomic.fna
# 18: 0.02) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964053065.1 -> GCF_964053065.1_30859_5_287_genomic.fna
# 19: 0.02) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040267585.1 -> GCF_040267585.1_MRSN129130_genomic.fna
# 20: 0.02) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884765.1 -> GCF_036884765.1_ASM3688476v1_genomic.fna
# 21: 0.03) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884635.1 -> GCF_036884635.1_ASM3688463v1_genomic.fna
# 22: 0.03) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884625.1 -> GCF_036884625.1_ASM3688462v1_genomic.fna
# 23: 0.03) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039912475.1 -> GCF_039912475.1_ASM3991247v1_genomic.fna
# 24: 0.03) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036923505.1 -> GCF_036923505.1_STEC28_genomic.fna
# 25: 0.03) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037914955.1 -> GCF_037914955.1_pKPC_NDMdeltaNDM_genomic.fna
# 26: 0.03) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039912655.1 -> GCF_039912655.1_ASM3991265v1_genomic.fna
# 27: 0.03) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039583295.1 -> GCF_039583295.1_ASM3958329v1_genomic.fna
# 28: 0.03) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964053065.1 -> GCF_964053065.1_30859_5_287_genomic.fna
# 29: 0.03) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040267585.1 -> GCF_040267585.1_MRSN129130_genomic.fna
# 30: 0.03) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884765.1 -> GCF_036884765.1_ASM3688476v1_genomic.fna
# 31: 0.04) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884635.1 -> GCF_036884635.1_ASM3688463v1_genomic.fna
# 32: 0.04) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884625.1 -> GCF_036884625.1_ASM3688462v1_genomic.fna
# 33: 0.04) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039912475.1 -> GCF_039912475.1_ASM3991247v1_genomic.fna
# 34: 0.04) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036923505.1 -> GCF_036923505.1_STEC28_genomic.fna
# 35: 0.04) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037914955.1 -> GCF_037914955.1_pKPC_NDMdeltaNDM_genomic.fna
# 36: 0.04) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039912655.1 -> GCF_039912655.1_ASM3991265v1_genomic.fna
# 37: 0.04) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039583295.1 -> GCF_039583295.1_ASM3958329v1_genomic.fna
# 38: 0.04) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964053065.1 -> GCF_964053065.1_30859_5_287_genomic.fna
# 39: 0.04) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040267585.1 -> GCF_040267585.1_MRSN129130_genomic.fna
# 40: 0.04) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884765.1 -> GCF_036884765.1_ASM3688476v1_genomic.fna
# 41: 0.06) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884635.1 -> GCF_036884635.1_ASM3688463v1_genomic.fna
# 42: 0.06) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884625.1 -> GCF_036884625.1_ASM3688462v1_genomic.fna
# 43: 0.06) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039912475.1 -> GCF_039912475.1_ASM3991247v1_genomic.fna
# 44: 0.06) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036923505.1 -> GCF_036923505.1_STEC28_genomic.fna
# 45: 0.06) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037914955.1 -> GCF_037914955.1_pKPC_NDMdeltaNDM_genomic.fna
# 46: 0.06) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039912655.1 -> GCF_039912655.1_ASM3991265v1_genomic.fna
# 47: 0.06) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039583295.1 -> GCF_039583295.1_ASM3958329v1_genomic.fna
# 48: 0.06) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964053065.1 -> GCF_964053065.1_30859_5_287_genomic.fna
# 49: 0.06) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040267585.1 -> GCF_040267585.1_MRSN129130_genomic.fna
# 50: 0.06) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884765.1 -> GCF_036884765.1_ASM3688476v1_genomic.fna
# 51: 0.07) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884635.1 -> GCF_036884635.1_ASM3688463v1_genomic.fna
# 52: 0.07) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884625.1 -> GCF_036884625.1_ASM3688462v1_genomic.fna
# 53: 0.07) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039912475.1 -> GCF_039912475.1_ASM3991247v1_genomic.fna
# 54: 0.07) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036923505.1 -> GCF_036923505.1_STEC28_genomic.fna
# 55: 0.07) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037914955.1 -> GCF_037914955.1_pKPC_NDMdeltaNDM_genomic.fna
# 56: 0.07) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039912655.1 -> GCF_039912655.1_ASM3991265v1_genomic.fna
# 57: 0.07) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039583295.1 -> GCF_039583295.1_ASM3958329v1_genomic.fna
# 58: 0.07) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964053065.1 -> GCF_964053065.1_30859_5_287_genomic.fna
# 59: 0.07) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040267585.1 -> GCF_040267585.1_MRSN129130_genomic.fna
# 60: 0.07) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884765.1 -> GCF_036884765.1_ASM3688476v1_genomic.fna
# 61: 0.08) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884635.1 -> GCF_036884635.1_ASM3688463v1_genomic.fna
# 62: 0.08) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884625.1 -> GCF_036884625.1_ASM3688462v1_genomic.fna
# 63: 0.08) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039912475.1 -> GCF_039912475.1_ASM3991247v1_genomic.fna
# 64: 0.08) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036923505.1 -> GCF_036923505.1_STEC28_genomic.fna
# 65: 0.08) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037914955.1 -> GCF_037914955.1_pKPC_NDMdeltaNDM_genomic.fna
# 66: 0.08) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039912655.1 -> GCF_039912655.1_ASM3991265v1_genomic.fna
# 67: 0.08) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039583295.1 -> GCF_039583295.1_ASM3958329v1_genomic.fna
# 68: 0.08) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964053065.1 -> GCF_964053065.1_30859_5_287_genomic.fna
# 69: 0.08) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040267585.1 -> GCF_040267585.1_MRSN129130_genomic.fna
# 70: 0.08) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884765.1 -> GCF_036884765.1_ASM3688476v1_genomic.fna
# 71: 0.09) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884635.1 -> GCF_036884635.1_ASM3688463v1_genomic.fna
# 72: 0.09) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884625.1 -> GCF_036884625.1_ASM3688462v1_genomic.fna
# 73: 0.09) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039912475.1 -> GCF_039912475.1_ASM3991247v1_genomic.fna
# 74: 0.09) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036923505.1 -> GCF_036923505.1_STEC28_genomic.fna
# 75: 0.09) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037914955.1 -> GCF_037914955.1_pKPC_NDMdeltaNDM_genomic.fna
# 76: 0.09) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039912655.1 -> GCF_039912655.1_ASM3991265v1_genomic.fna
# 77: 0.09) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039583295.1 -> GCF_039583295.1_ASM3958329v1_genomic.fna
# 78: 0.09) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964053065.1 -> GCF_964053065.1_30859_5_287_genomic.fna
# 79: 0.09) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040267585.1 -> GCF_040267585.1_MRSN129130_genomic.fna
# 80: 0.09) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884765.1 -> GCF_036884765.1_ASM3688476v1_genomic.fna
# 81: 0.1) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884635.1 -> GCF_036884635.1_ASM3688463v1_genomic.fna
# 82: 0.1) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884625.1 -> GCF_036884625.1_ASM3688462v1_genomic.fna
# 83: 0.1) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039912475.1 -> GCF_039912475.1_ASM3991247v1_genomic.fna
# 84: 0.1) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036923505.1 -> GCF_036923505.1_STEC28_genomic.fna
# 85: 0.1) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_037914955.1 -> GCF_037914955.1_pKPC_NDMdeltaNDM_genomic.fna
# 86: 0.1) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039912655.1 -> GCF_039912655.1_ASM3991265v1_genomic.fna
# 87: 0.1) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_039583295.1 -> GCF_039583295.1_ASM3958329v1_genomic.fna
# 88: 0.1) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_964053065.1 -> GCF_964053065.1_30859_5_287_genomic.fna
# 89: 0.1) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_040267585.1 -> GCF_040267585.1_MRSN129130_genomic.fna
# 90: 0.1) /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884765.1 -> GCF_036884765.1_ASM3688476v1_genomic.fna
# Done

# %%
# Get paths of new genomes
# See if there has been a 5% change in each, get length of orginal, length of change and difference value between them.ls
ani_genomes = []
end_pattern = ".fna"
mod_patterns = ["SNP_0.01", "SNP_0.02", "SNP_0.03", "SNP_0.04", "SNP_0.05", "SNP_0.06", "SNP_0.07", "SNP_0.08", "SNP_0.09", "SNP_0.1"]
bad_pattern = ".fai"

directory_count = 0
for root, dirs, files in os.walk(start_directory):
    if directory_count > 10:  # Stop after checking 10 directories
        break
    
    for file in files:
        if end_pattern in file and any(mod_pattern in file for mod_pattern in mod_patterns) and bad_pattern not in file:
            ani_genomes.append(os.path.join(root, file))

    directory_count += 1

print(len(ani_genomes))
print(ani_genomes[0])
# Out:
# 90
# /home/ftoon/Tests/TestingDatasets/ncbi_dataset_simuG_same/data/GCF_036884635.1/SNP_0.01_GCF_036884635.1_ASM3688463v1_genomic.fna

# %%
# Get the first ten directories
dir_ten = new_dir[0:10]

# Extract the SNP_0.01 pattern 
for file_path in ani_genomes:

    # Figure out which number it is
    snp_pattern = re.search(r'SNP_\d+\.\d+', file_path)
    if snp_pattern:
        snp_full = snp_pattern.group(0)
    
        # Extract the numeric value from the SNP_0.01 pattern
        snp_value = re.search(r'\d+\.\d+', snp_full)
        if snp_value:
            snp_numeric = snp_value.group(0)

    # Get the OG dir
    og_dir = re.split(r'SNP_', file_path)[0]

    # Get the OG file
    matching_path = None
    for path in original_genomes:
        if path.startswith(og_dir):
            matching_path = path
            break

    command = f'cd {og_dir} && /opt/FastANI-v1.34/fastANI -r {matching_path} -q {file_path} -o {og_dir}/{snp_numeric}_fastani.txt'
    try:
        # Run the command in the shell with a timeout of 3 minutes
        result = subprocess.run(command, shell=True, timeout=3*60, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL, universal_newlines=True)

        # Print stderr output
        if result.stderr:
            print(result.stderr)
                
    except subprocess.TimeoutExpired as e:
        print(f"Command timed out: {e}")
    except Exception as e:
        print(f"An error occurred: {e}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 30
#      27 command = f'cd {og_dir} && /opt/FastANI-v1.34/fastANI -r {matching_path} -q {file_path} -o {og_dir}/{snp_numeric}_fastani.txt'
#      28 try:
#      29     # Run the command in the shell with a timeout of 3 minutes
# ---> 30     result = subprocess.run(command, shell=True, timeout=3*60, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL, universal_newlines=True)
#      32     # Print stderr output
#      33     if result.stderr:
#
# File /usr/lib/python3.10/subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     503 with Popen(*popenargs, **kwargs) as process:
#     504     try:
# --> 505         stdout, stderr = process.communicate(input, timeout=timeout)
#     506     except TimeoutExpired as exc:
#     507         process.kill()
#
# File /usr/lib/python3.10/subprocess.py:1154, in Popen.communicate(self, input, timeout)
#    1151     endtime = None
#    1153 try:
# -> 1154     stdout, stderr = self._communicate(input, endtime, timeout)
#    1155 except KeyboardInterrupt:
#    1156     # https://bugs.python.org/issue25942
#    1157     # See the detailed comment in .wait().
#    1158     if timeout is not None:
#
# File /usr/lib/python3.10/subprocess.py:2047, in Popen._communicate(self, input, endtime, orig_timeout)
#    2044                     key.fileobj.close()
#    2045                 self._fileobj2output[key.fileobj].append(data)
# -> 2047 self.wait(timeout=self._remaining_time(endtime))
#    2049 # All data exchanged.  Translate lists into strings.
#    2050 if stdout is not None:
#
# File /usr/lib/python3.10/subprocess.py:1209, in Popen.wait(self, timeout)
#    1207     endtime = _time() + timeout
#    1208 try:
# -> 1209     return self._wait(timeout=timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # The first keyboard interrupt waits briefly for the child to
#    1213     # exit under the common assumption that it also received the ^C
#    1214     # generated SIGINT and will exit rapidly.
#    1215     if timeout is not None:
#
# File /usr/lib/python3.10/subprocess.py:1953, in Popen._wait(self, timeout)
#    1951             raise TimeoutExpired(self.args, timeout)
#    1952         delay = min(delay * 2, remaining, .05)
# -> 1953         time.sleep(delay)
#    1954 else:
#    1955     while self.returncode is None:
#
# KeyboardInterrupt:

# %%
# List to store ANI values
ani_test_results = []
dir_ten = new_dir[0:10]
for folder in dir_ten:
    try:
        for root, _, files in os.walk(folder):
            for file in files:
                if '_fastani' in file:
                    if file[0:4] == "0.1_":
                        file_id = float(file[0:3])
                    else:
                        file_id = float(file[0:4])
                    file_path = os.path.join(root, file)

                    # Open and read the file
                    with open(file_path, 'r') as f:
                        for line in f:
                            parts = line.strip().split('\t')
                            if len(parts) >= 3:
                                try:
                                    ani_value = float(parts[2])
                                    ani_test_results.append([folder[63:], file_id, ani_value])
                                except ValueError:
                                    print(f"Could not convert ANI value to float: {parts[2]}")
    except Exception as e:
        print(f"An error occurred while processing files in folder {folder}: {e}")


print(len(ani_test_results))
# Out:
# 100

# %%
# Create a dictionary to store data by legend
data_dict = {}
for entry in ani_test_results:
    legend, x, y = entry
    if legend not in data_dict:
        data_dict[legend] = {'x': [], 'y': []}
    data_dict[legend]['x'].append(x)
    data_dict[legend]['y'].append(y)

# Plotting
plt.figure(figsize=(6, 4))

for legend, values in data_dict.items():
    # Scatter plot
    plt.scatter(values['x'], values['y'], label=legend)
    # Line plot to connect the dots
    #plt.plot(values['x'], values['y'], linestyle='-', marker='o')

plt.xlabel('SNP Rate')
plt.ylabel('ANI Score')
plt.title('SimuG Simulator Same Species: ANI Score vs SNP Rate')
# Adjust the legend to be outside the plot
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), borderaxespad=1)
plt.show()
